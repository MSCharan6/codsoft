# %% [markdown]
# <a href="https://colab.research.google.com/github/MSCharan6/codsoft/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import cv2
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import resnet
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

def generate_image_pairs(images, labels):
    # Generate index for each label
    unique_labels = np.unique(labels)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels) if
                                       label == curr_label])

    # Generate image pairs and labels
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images):
        pos_indices = label_wise_indices.get(labels[index])
        pos_image = images[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels != labels[index])
        neg_image = images[np.random.choice(neg_indices[0])]
        pair_images.append((image, neg_image))
        pair_labels.append(0)

    return np.array(pair_images), np.array(pair_labels)

faces = '../input/olivetti/olivetti_faces.npy'
faces_targets = '../input/olivetti/olivetti_faces_target.npy'

# !pip install scikit-learn
from sklearn.datasets import fetch_olivetti_faces

# Fetch the Olivetti faces dataset
faces = fetch_olivetti_faces()

# Access the images and labels
face_images = faces.images
face_labels = faces.target

target_shape = face_images[0].shape

images_dataset, labels_dataset = generate_image_pairs(face_images, face_labels)
images_dataset, labels_dataset = shuffle(images_dataset, labels_dataset)

def visualize(image_pairs, labels, n = 5, title = "Image Pair Examples"):
    """ Visualize a few pairs """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    plt.title(title)
    axs = fig.subplots(n, 2)
    for i in range(n):
        show(axs[i, 0], image_pairs[i][0])
        show(axs[i, 1], image_pairs[i][1])

n = 5
indices = np.where(labels_dataset == 1)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Positive Image Examples")

n = 5
indices = np.where(labels_dataset == 0)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Negative Image Examples")

inputs = layers.Input((64, 64, 1))

x = layers.Conv2D(64, (10, 10), padding="same", activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (7, 7), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (4, 4), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(256, (4, 4), padding="same", activation="relu")(x)
fcOutput = layers.Flatten()(x)
fcOutput = layers.Dense(4096, activation = "relu")(fcOutput)
outputs = layers.Dense(1024, activation = "sigmoid")(fcOutput)

embedding = Model(inputs, outputs, name = "Embedding")

import tensorflow.keras.backend as K

def contrastive_loss(y, preds, margin=1):
    y = tf.cast(y, preds.dtype)
    squaredPreds = K.square(preds)
    squaredMargin = K.square(K.maximum(margin - preds, 0))
    loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)

    return loss

class DistanceLayer(layers.Layer):
    """
    This layer is responsible for computing the distance
    between the embeddings
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, compare):
        sum_squared = K.sum(K.square(anchor - compare), axis=1, keepdims=True)
        return K.sqrt(K.maximum(sum_squared, K.epsilon()))


anchor_input = layers.Input(name="anchor", shape=target_shape + (1,))
compare_input = layers.Input(name="compare", shape=target_shape + (1,))

distances = DistanceLayer()(
    embedding(anchor_input),
    embedding(compare_input),
)

outputs = layers.Dense(1, activation = "sigmoid") (distances)

siamese_model = Model(
    inputs=[anchor_input, compare_input], outputs=outputs
)

siamese_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
history = siamese_model.fit([images_dataset[:, 0, :], images_dataset[:, 1, :]], labels_dataset,
                            epochs=150, validation_split = 0.2, batch_size = 64)

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])

def test_visualize(images, n = 5):
    """ Visualize a few images """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    axs = fig.subplots(1, n)
    for i in range(n):
        show(axs[i], images[i])

test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

plt.imshow(test_image)

test_visualize(compare_images)

image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))

image_pairs = np.array(image_pairs)

score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])

print(score)

test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10, 20), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

plt.imshow(test_image)

test_visualize(compare_images)

image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))

image_pairs = np.array(image_pairs)

score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])
print(score)
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 132s 13s/step - accuracy: 0.5241 - loss: 0.6731 - val_accuracy: 0.4875 - val_loss: 0.6792
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 13s/step - accuracy: 0.5216 - loss: 0.6207 - val_accuracy: 0.5437 - val_loss: 0.6663
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - accuracy: 0.4844 - loss: 0.6260 - val_accuracy: 0.5688 - val_loss: 0.6717
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 128s 13s/step - accuracy: 0.5426 - loss: 0.5932 - val_accuracy: 0.4875 - val_loss: 0.6446
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.5085 - loss: 0.6018 - val_accuracy: 0.4875 - val_loss: 0.6346
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.5327 - loss: 0.5744 - val_accuracy: 0.5312 - val_loss: 0.6309
# Epoch 7/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.5470 - loss: 0.5724 - val_accuracy: 0.5500 - val_loss: 0.6204
# Epoch 8/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - accuracy: 0.5439 - loss: 0.5738 - val_accuracy: 0.6125 - val_loss: 0.6409
# Epoch 9/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 146s 13s/step - accuracy: 0.5803 - loss: 0.5799 - val_accuracy: 0.5625 - val_loss: 0.6208
# Epoch 10/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.5322 - loss: 0.5797 - val_accuracy: 0.5437 - val_loss: 0.6190
# Epoch 11/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 12s/step - accuracy: 0.5548 - loss: 0.5788 - val_accuracy: 0.5500 - val_loss: 0.6261
# Epoch 12/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.5465 - loss: 0.5832 - val_accuracy: 0.5312 - val_loss: 0.6571
# Epoch 13/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.5594 - loss: 0.5754 - val_accuracy: 0.6062 - val_loss: 0.6165
# Epoch 14/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.5417 - loss: 0.5907 - val_accuracy: 0.5312 - val_loss: 0.6257
# Epoch 15/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.5767 - loss: 0.5401 - val_accuracy: 0.6562 - val_loss: 0.6168
# Epoch 16/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.6031 - loss: 0.5890 - val_accuracy: 0.5688 - val_loss: 0.6098
# Epoch 17/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - accuracy: 0.5494 - loss: 0.5522 - val_accuracy: 0.6187 - val_loss: 0.5918
# Epoch 18/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.5927 - loss: 0.5718 - val_accuracy: 0.6250 - val_loss: 0.5914
# Epoch 19/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.6175 - loss: 0.5358 - val_accuracy: 0.6000 - val_loss: 0.5812
# Epoch 20/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.5791 - loss: 0.5574 - val_accuracy: 0.6438 - val_loss: 0.5913
# Epoch 21/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.5805 - loss: 0.5440 - val_accuracy: 0.6000 - val_loss: 0.6030
# Epoch 22/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.5999 - loss: 0.5291 - val_accuracy: 0.5875 - val_loss: 0.5781
# Epoch 23/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 12s/step - accuracy: 0.6143 - loss: 0.5164 - val_accuracy: 0.6438 - val_loss: 0.5682
# Epoch 24/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.6712 - loss: 0.4939 - val_accuracy: 0.7188 - val_loss: 0.6004
# Epoch 25/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.6772 - loss: 0.5075 - val_accuracy: 0.5813 - val_loss: 0.5522
# Epoch 26/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 12s/step - accuracy: 0.6355 - loss: 0.5091 - val_accuracy: 0.7063 - val_loss: 0.5508
# Epoch 27/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.6537 - loss: 0.4940 - val_accuracy: 0.6125 - val_loss: 0.5499
# Epoch 28/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.7048 - loss: 0.4961 - val_accuracy: 0.7312 - val_loss: 0.5587
# Epoch 29/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.6686 - loss: 0.5075 - val_accuracy: 0.6750 - val_loss: 0.5340
# Epoch 30/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.6765 - loss: 0.4526 - val_accuracy: 0.7125 - val_loss: 0.5212
# Epoch 31/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 12s/step - accuracy: 0.7528 - loss: 0.4657 - val_accuracy: 0.6938 - val_loss: 0.5468
# Epoch 32/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.7179 - loss: 0.4679 - val_accuracy: 0.7500 - val_loss: 0.5198
# Epoch 33/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.7470 - loss: 0.4335 - val_accuracy: 0.7063 - val_loss: 0.5824
# Epoch 34/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.6961 - loss: 0.4896 - val_accuracy: 0.6750 - val_loss: 0.5473
# Epoch 35/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.7548 - loss: 0.4626 - val_accuracy: 0.6875 - val_loss: 0.5448
# Epoch 36/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.7608 - loss: 0.4553 - val_accuracy: 0.7188 - val_loss: 0.5228
# Epoch 37/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.7720 - loss: 0.4359 - val_accuracy: 0.8375 - val_loss: 0.4616
# Epoch 38/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 13s/step - accuracy: 0.8284 - loss: 0.4222 - val_accuracy: 0.7437 - val_loss: 0.5381
# Epoch 39/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.8216 - loss: 0.4115 - val_accuracy: 0.7437 - val_loss: 0.4915
# Epoch 40/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - accuracy: 0.8331 - loss: 0.4053 - val_accuracy: 0.7875 - val_loss: 0.4857
# Epoch 41/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.8365 - loss: 0.4137 - val_accuracy: 0.7937 - val_loss: 0.4768
# Epoch 42/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 13s/step - accuracy: 0.8889 - loss: 0.3948 - val_accuracy: 0.7188 - val_loss: 0.5086
# Epoch 43/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 12s/step - accuracy: 0.8303 - loss: 0.3973 - val_accuracy: 0.8313 - val_loss: 0.4605
# Epoch 44/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 12s/step - accuracy: 0.8738 - loss: 0.4052 - val_accuracy: 0.8188 - val_loss: 0.4860
# Epoch 45/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.8776 - loss: 0.3710 - val_accuracy: 0.8500 - val_loss: 0.4634
# Epoch 46/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 13s/step - accuracy: 0.8843 - loss: 0.3760 - val_accuracy: 0.7875 - val_loss: 0.5035
# Epoch 47/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9032 - loss: 0.3870 - val_accuracy: 0.8062 - val_loss: 0.4778
# Epoch 48/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8763 - loss: 0.3929 - val_accuracy: 0.8500 - val_loss: 0.4644
# Epoch 49/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.8800 - loss: 0.3717 - val_accuracy: 0.7063 - val_loss: 0.5481
# Epoch 50/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 12s/step - accuracy: 0.8720 - loss: 0.3900 - val_accuracy: 0.8188 - val_loss: 0.4609
# Epoch 51/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9119 - loss: 0.3600 - val_accuracy: 0.7250 - val_loss: 0.5551
# Epoch 52/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.8731 - loss: 0.3832 - val_accuracy: 0.8813 - val_loss: 0.4169
# Epoch 53/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 13s/step - accuracy: 0.9003 - loss: 0.3728 - val_accuracy: 0.8125 - val_loss: 0.4800
# Epoch 54/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.8846 - loss: 0.3722 - val_accuracy: 0.8687 - val_loss: 0.4591
# Epoch 55/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9251 - loss: 0.3487 - val_accuracy: 0.8375 - val_loss: 0.4567
# Epoch 56/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 12s/step - accuracy: 0.8851 - loss: 0.3632 - val_accuracy: 0.7875 - val_loss: 0.5201
# Epoch 57/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.8733 - loss: 0.3804 - val_accuracy: 0.8625 - val_loss: 0.4504
# Epoch 58/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9227 - loss: 0.3395 - val_accuracy: 0.8625 - val_loss: 0.4310
# Epoch 59/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.8996 - loss: 0.3483 - val_accuracy: 0.8375 - val_loss: 0.4786
# Epoch 60/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9366 - loss: 0.3548 - val_accuracy: 0.8125 - val_loss: 0.4581
# Epoch 61/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9296 - loss: 0.3372 - val_accuracy: 0.7937 - val_loss: 0.4628
# Epoch 62/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9052 - loss: 0.3631 - val_accuracy: 0.8562 - val_loss: 0.4303
# Epoch 63/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9196 - loss: 0.3497 - val_accuracy: 0.8750 - val_loss: 0.4194
# Epoch 64/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9012 - loss: 0.3548 - val_accuracy: 0.8625 - val_loss: 0.4154
# Epoch 65/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9131 - loss: 0.3471 - val_accuracy: 0.8813 - val_loss: 0.4041
# Epoch 66/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9067 - loss: 0.3464 - val_accuracy: 0.8813 - val_loss: 0.3896
# Epoch 67/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - accuracy: 0.8655 - loss: 0.3957 - val_accuracy: 0.7875 - val_loss: 0.4840
# Epoch 68/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 13s/step - accuracy: 0.9199 - loss: 0.3331 - val_accuracy: 0.8938 - val_loss: 0.4344
# Epoch 69/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9540 - loss: 0.3001 - val_accuracy: 0.8813 - val_loss: 0.4422
# Epoch 70/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 128s 13s/step - accuracy: 0.9634 - loss: 0.2944 - val_accuracy: 0.8125 - val_loss: 0.4997
# Epoch 71/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9469 - loss: 0.3031 - val_accuracy: 0.8375 - val_loss: 0.4541
# Epoch 72/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 127s 13s/step - accuracy: 0.9563 - loss: 0.3032 - val_accuracy: 0.8062 - val_loss: 0.4950
# Epoch 73/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9595 - loss: 0.2863 - val_accuracy: 0.8813 - val_loss: 0.4039
# Epoch 74/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9460 - loss: 0.3047 - val_accuracy: 0.8562 - val_loss: 0.4656
# Epoch 75/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9296 - loss: 0.3156 - val_accuracy: 0.8938 - val_loss: 0.3940
# Epoch 76/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9315 - loss: 0.3132 - val_accuracy: 0.9125 - val_loss: 0.3760
# Epoch 77/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9212 - loss: 0.3157 - val_accuracy: 0.8750 - val_loss: 0.4073
# Epoch 78/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.9279 - loss: 0.3153 - val_accuracy: 0.8875 - val_loss: 0.4148
# Epoch 79/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 127s 13s/step - accuracy: 0.9543 - loss: 0.2929 - val_accuracy: 0.8500 - val_loss: 0.4948
# Epoch 80/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9498 - loss: 0.2844 - val_accuracy: 0.8813 - val_loss: 0.4089
# Epoch 81/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9440 - loss: 0.2845 - val_accuracy: 0.8687 - val_loss: 0.4227
# Epoch 82/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 130s 13s/step - accuracy: 0.9678 - loss: 0.2553 - val_accuracy: 0.8562 - val_loss: 0.4535
# Epoch 83/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 13s/step - accuracy: 0.9638 - loss: 0.2582 - val_accuracy: 0.9125 - val_loss: 0.3741
# Epoch 84/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9653 - loss: 0.2653 - val_accuracy: 0.8875 - val_loss: 0.3891
# Epoch 85/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9676 - loss: 0.2406 - val_accuracy: 0.8625 - val_loss: 0.4520
# Epoch 86/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9698 - loss: 0.2535 - val_accuracy: 0.8313 - val_loss: 0.4236
# Epoch 87/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.9609 - loss: 0.2548 - val_accuracy: 0.8625 - val_loss: 0.4048
# Epoch 88/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9610 - loss: 0.2545 - val_accuracy: 0.9000 - val_loss: 0.3655
# Epoch 89/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9506 - loss: 0.2579 - val_accuracy: 0.9062 - val_loss: 0.3804
# Epoch 90/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9573 - loss: 0.2395 - val_accuracy: 0.8687 - val_loss: 0.4058
# Epoch 91/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 128s 13s/step - accuracy: 0.9599 - loss: 0.2587 - val_accuracy: 0.8687 - val_loss: 0.3952
# Epoch 92/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.9481 - loss: 0.2578 - val_accuracy: 0.8875 - val_loss: 0.3908
# Epoch 93/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9628 - loss: 0.2522 - val_accuracy: 0.8938 - val_loss: 0.3560
# Epoch 94/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9582 - loss: 0.2495 - val_accuracy: 0.8750 - val_loss: 0.4300
# Epoch 95/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9646 - loss: 0.2369 - val_accuracy: 0.8687 - val_loss: 0.4275
# Epoch 96/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9610 - loss: 0.2343 - val_accuracy: 0.8313 - val_loss: 0.5080
# Epoch 97/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9607 - loss: 0.2477 - val_accuracy: 0.7750 - val_loss: 0.5757
# Epoch 98/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9619 - loss: 0.2421 - val_accuracy: 0.9125 - val_loss: 0.3637
# Epoch 99/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9650 - loss: 0.2491 - val_accuracy: 0.8938 - val_loss: 0.3135
# Epoch 100/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 127s 13s/step - accuracy: 0.9253 - loss: 0.2943 - val_accuracy: 0.8875 - val_loss: 0.3499
# Epoch 101/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 13s/step - accuracy: 0.9342 - loss: 0.2749 - val_accuracy: 0.8750 - val_loss: 0.3825
# Epoch 102/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 13s/step - accuracy: 0.9613 - loss: 0.2359 - val_accuracy: 0.8750 - val_loss: 0.3828
# Epoch 103/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9494 - loss: 0.2415 - val_accuracy: 0.9187 - val_loss: 0.3217
# Epoch 104/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9510 - loss: 0.2304 - val_accuracy: 0.9187 - val_loss: 0.3247
# Epoch 105/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.9681 - loss: 0.2194 - val_accuracy: 0.8813 - val_loss: 0.4093
# Epoch 106/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 13s/step - accuracy: 0.9742 - loss: 0.2236 - val_accuracy: 0.8938 - val_loss: 0.3591
# Epoch 107/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9673 - loss: 0.2176 - val_accuracy: 0.9125 - val_loss: 0.3246
# Epoch 108/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 128s 13s/step - accuracy: 0.9790 - loss: 0.1986 - val_accuracy: 0.9187 - val_loss: 0.3068
# Epoch 109/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9635 - loss: 0.2083 - val_accuracy: 0.9125 - val_loss: 0.3381
# Epoch 110/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9679 - loss: 0.2157 - val_accuracy: 0.8625 - val_loss: 0.4334
# Epoch 111/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9618 - loss: 0.2338 - val_accuracy: 0.8938 - val_loss: 0.3268
# Epoch 112/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9629 - loss: 0.2140 - val_accuracy: 0.9125 - val_loss: 0.3228
# Epoch 113/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9745 - loss: 0.2011 - val_accuracy: 0.8750 - val_loss: 0.3822
# Epoch 114/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9571 - loss: 0.2177 - val_accuracy: 0.9000 - val_loss: 0.3417
# Epoch 115/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9542 - loss: 0.2278 - val_accuracy: 0.8938 - val_loss: 0.3574
# Epoch 116/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.9476 - loss: 0.2613 - val_accuracy: 0.8625 - val_loss: 0.4117
# Epoch 117/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9400 - loss: 0.2620 - val_accuracy: 0.8188 - val_loss: 0.5403
# Epoch 118/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9288 - loss: 0.2503 - val_accuracy: 0.9187 - val_loss: 0.3041
# Epoch 119/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9708 - loss: 0.2063 - val_accuracy: 0.9250 - val_loss: 0.2954
# Epoch 120/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9528 - loss: 0.2351 - val_accuracy: 0.8938 - val_loss: 0.3435
# Epoch 121/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.9497 - loss: 0.2345 - val_accuracy: 0.8687 - val_loss: 0.3565
# Epoch 122/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9560 - loss: 0.2195 - val_accuracy: 0.8875 - val_loss: 0.3499
# Epoch 123/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9558 - loss: 0.2172 - val_accuracy: 0.8813 - val_loss: 0.3735
# Epoch 124/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9578 - loss: 0.2267 - val_accuracy: 0.8562 - val_loss: 0.4075
# Epoch 125/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9534 - loss: 0.2329 - val_accuracy: 0.9062 - val_loss: 0.3361
# Epoch 126/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9546 - loss: 0.2178 - val_accuracy: 0.9062 - val_loss: 0.3773
# Epoch 127/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9786 - loss: 0.1854 - val_accuracy: 0.8500 - val_loss: 0.4842
# Epoch 128/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9668 - loss: 0.2022 - val_accuracy: 0.9062 - val_loss: 0.3656
# Epoch 129/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9788 - loss: 0.1882 - val_accuracy: 0.9000 - val_loss: 0.3895
# Epoch 130/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9654 - loss: 0.1892 - val_accuracy: 0.8625 - val_loss: 0.4628
# Epoch 131/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.9744 - loss: 0.1797 - val_accuracy: 0.9125 - val_loss: 0.3696
# Epoch 132/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9770 - loss: 0.1853 - val_accuracy: 0.9125 - val_loss: 0.3129
# Epoch 133/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9703 - loss: 0.1848 - val_accuracy: 0.8938 - val_loss: 0.3973
# Epoch 134/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9797 - loss: 0.1870 - val_accuracy: 0.9125 - val_loss: 0.3322
# Epoch 135/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9711 - loss: 0.1748 - val_accuracy: 0.9062 - val_loss: 0.3421
# Epoch 136/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9775 - loss: 0.1714 - val_accuracy: 0.8938 - val_loss: 0.3613
# Epoch 137/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9631 - loss: 0.1959 - val_accuracy: 0.9125 - val_loss: 0.3362
# Epoch 138/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 127s 13s/step - accuracy: 0.9756 - loss: 0.1794 - val_accuracy: 0.9187 - val_loss: 0.3474
# Epoch 139/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9767 - loss: 0.1784 - val_accuracy: 0.8687 - val_loss: 0.5217
# Epoch 140/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9378 - loss: 0.2363 - val_accuracy: 0.8438 - val_loss: 0.4522
# Epoch 141/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 146s 13s/step - accuracy: 0.9565 - loss: 0.2111 - val_accuracy: 0.9062 - val_loss: 0.3173
# Epoch 142/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9683 - loss: 0.1851 - val_accuracy: 0.8750 - val_loss: 0.4238
# Epoch 143/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9616 - loss: 0.2076 - val_accuracy: 0.8625 - val_loss: 0.4455
# Epoch 144/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 126s 13s/step - accuracy: 0.9653 - loss: 0.1900 - val_accuracy: 0.8813 - val_loss: 0.3387
# Epoch 145/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9587 - loss: 0.1962 - val_accuracy: 0.8938 - val_loss: 0.3726
# Epoch 146/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 125s 13s/step - accuracy: 0.9663 - loss: 0.1834 - val_accuracy: 0.9062 - val_loss: 0.2979
# Epoch 147/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9772 - loss: 0.1628 - val_accuracy: 0.8938 - val_loss: 0.3374
# Epoch 148/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9756 - loss: 0.1705 - val_accuracy: 0.9062 - val_loss: 0.3577
# Epoch 149/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9746 - loss: 0.1687 - val_accuracy: 0.9000 - val_loss: 0.4005
# Epoch 150/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9837 - loss: 0.1692 - val_accuracy: 0.8875 - val_loss: 0.4405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# [[7.8522146e-01]
#  [7.8522146e-01]
#  [2.2863375e-03]
#  [1.8772726e-03]
#  [6.1245129e-04]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# [[7.8522146e-01]
#  [7.8522146e-01]
#  [1.8773547e-03]
#  [1.8773029e-03]
#  [6.1225577e-04]]

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])
